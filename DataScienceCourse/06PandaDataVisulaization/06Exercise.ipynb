# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df3 = pd.read_csv('df3')

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a',y='b',figsize=(12,3),color='firebrick',s =50)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].plot.hist(color = 'lightsalmon',bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df3[['a','b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.kde(color='tomato',linestyle='--',linewidth=3)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3
# Out:
#             a         b         c         d
# 0    0.336272  0.325011  0.001020  0.401402
# 1    0.980265  0.831835  0.772288  0.076485
# 2    0.480387  0.686839  0.000575  0.746758
# 3    0.502106  0.305142  0.768608  0.654685
# 4    0.856602  0.171448  0.157971  0.321231
# ..        ...       ...       ...       ...
# 495  0.528705  0.226122  0.055835  0.131962
# 496  0.324730  0.215201  0.935302  0.794115
# 497  0.118036  0.264574  0.629206  0.824062
# 498  0.227021  0.660209  0.851353  0.478676
# 499  0.466157  0.753000  0.115391  0.279712
#
# [500 rows x 4 columns]

# %%
df3.plot.area()
# Out:
# <AxesSubplot:>

# %%
df3.iloc[0:30].plot.area(alpha=0.5).legend(loc='center left',bbox_to_anchor=(1,0.5))
